# %% [markdown]
# # Pesquisa Operacional
#
# ## Minimização

# %% [markdown]
# ### Exercício

# %% [markdown]
# <p style="text-align: justify; text-indent: 2rem">
#     Uma granja quer misturar dois tipos de alimentos para criar um tipo especial de ração para suas galinhas poedeiras. A primeira característica a ser atingida com a nova ração é o menor preço possível por unidade de massa.
# </p>
# <p style="text-align: justify; text-indent: 2rem">
#     Cada um dos alimentos contém os nutrientes necessários à ração final (digamos, $A$, $B$ e $C$), porém em proporções variáveis. Cada 100 gramas do alimento $X$ possuem 10g do nutriente $A$, 50g do nutriente $B$ e 40g do nutriente $C$. Já o alimento $Y$, por sua vez, para cada 100g, possui 20g do nutriente $A$, 60g do nutriente $B$ e 20g do nutriente $C$. Cada 100 gramas do alimento $X$ custam R\$0,60 e cada 100 gramas do alimento $Y$ custam R\$0,80.
# </p>
# <p style="text-align: justify; text-indent: 2rem">
#     Sabe-se que a ração final deve conter, no mínimo, 2g do nutriente $A$, 64g do nutriente $B$ e 34g do nutriente $C$.
#     Escreva e resolva o problema de pesquisa operacional que obedeça a essa composição da ração e que ao mesmo tempo minimize o custo por massa da nova ração.
# </p>

# %% [markdown]
# ### _Solução: Resumo dos dados_.

# %% [markdown]
# <table style="border: 1px solid black">
#     <tr style="border: 1px solid black">
#         <th style="border: 1px solid black"></th>
#         <th colspan="2" style="border: 1px solid black">Composição por 100g</th>
#         <th rowspan="2" style="width:160px">Composição de nutrientes (mínima em g)</th>
#     </tr>
#     <tr style="border: 1px solid black">
#         <th style="border: 1px solid black"></th>
#         <th style="border: 1px solid black">Ração X</th>
#         <th style="border: 1px solid black">Ração Y</th>
#     </tr>
#     <tr style="border: 1px solid blac">
#         <td style="border: 1px solid black">Nutriente A</td>
#         <td style="text-align: center; border: 1px solid black">10</td>
#         <td style="text-align: center; border: 1px solid black">20</td>
#         <td style="text-align: center; border: 1px solid black">2</td>
#     </tr>
#     <tr style="border: 1px solid black">
#         <td style="border: 1px solid black">Nutriente B</td>
#         <td style="text-align: center; border: 1px solid black">50</td>
#         <td style="text-align: center; border: 1px solid black">60</td>
#         <td style="text-align: center; border: 1px solid black">64</td>
#     </tr>
#     <tr style="border: 1px solid black">
#         <td style="border: 1px solid black">Nutriente C</td>
#         <td style="text-align: center; border: 1px solid black">40</td>
#         <td style="text-align: center; border: 1px solid black">20</td>
#         <td style="text-align: center; border: 1px solid black">34</td>
#     </tr>
#     <tr style="border: 1px solid black">
#         <td style="border: 1px solid black">Custo por 100g</td>
#         <td style="text-align: center; border: 1px solid black">R\$ 0,60</td>
#         <td style="text-align: center; border: 1px solid black">R\$ 0,80</td>
#         <td style="border: 1px solid black"></td>
#     </tr>
# </table>

# %% [markdown]
# ### Função objetivo:

# %% [markdown]
# $ Mín \quad \quad C(X, Y )= 0,006X + 0,008Y $

# %% [markdown]
# Sujeito a:

# %% [markdown]
# Restrição do Nutriente $A: \quad \quad 0,10X + 0,20Y \ge 2 $

# %% [markdown]
# Restrição do Nutriente $B: \quad \quad 0,50X + 0,60Y \ge 64 $

# %% [markdown]
# Restrição do Nutriente $C: \quad \quad 0,40X + 0,20Y \ge 34 $

# %% [markdown]
# $ X \ge 0 $
#
# $ Y \ge 0 $

# %% [markdown]
# ![grafico-ex-minimizacao-2.png](attachment:deae68d0-6dcb-4392-8b8e-284eb62fbae4.png)

# %% [markdown]
# A área formada pela restrição do nutriente $A$ (restrição 1) é naturalmente excluída pelas restrições 2 e 3 (nutrientes $B$ e $C$).

# %% [markdown]
# Analisando a função objetivo nos pontos de restrição $P1$, $P2$ e $P3$ temos:

# %% [markdown]
# $ P1=(0,170) \quad \quad C = 0,006.0 + 0,008.170 = 1.36$
#
# $P2=(54.3,61.4) \quad \quad C = 0,006.54,3 + 0,008.61,4 = 0,817$
#
# $P3=(128,0) \quad \quad C = 0,006.128 + 0,008.0 = 0,768$

# %% [markdown]
# ### Usando o Solver do Excel

# %% [markdown]
# ![1_excel-solver-minimizacao-ex-2.png](attachment:d76d1cdd-e3ee-4c27-9c72-61d13e2c7d38.png)

# %% [markdown]
# ![2_excel-solver-minimizacao-ex-2.png](attachment:83735f09-6536-41af-a228-3aee90fb30b2.png)

# %% [markdown]
# ![3_excel-solver-minimizacao-ex-2.png](attachment:9bbc8559-a022-4c0c-96a9-23ab74626773.png)

# %% [markdown]
# Em dados > solver

# %% [markdown]
# ![4_excel-solver-minimizacao-ex-2.png](attachment:acea329d-7223-4979-ba2c-b37c876ea4ee.png)

# %% [markdown]
# ![5_excel-solver-minimizacao-ex-2.png](attachment:f652cd00-4866-4d1d-9eef-db50d3a82934.png)
