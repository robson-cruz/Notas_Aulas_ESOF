# %% [markdown]
# # SQL
#
# ## FUNÇÕES NATIVAS SQL

# %% [markdown]
# ### FUNÇÕES DE AGRUPAMENTO

# %% [markdown]
# ### FUNÇÕES PARA MANIPULAR STRINGS

# %% [markdown]
# #### LEFT

# %% [markdown]
# A função `LEFT` no SQL é usada para retornar um número específico de caracteres do início de uma cadeia de caracteres (string). Sua sintaxe básica é: `LEFT(string, length)
# . No exemplo a seguir, demonstraremos como extrair os 4 primeiros caracteres, ou seja, partir da esquerda, dos nomes presentes na tabela `customer` da base de dados `sakila` do MySQL.`

# %% [markdown]
# ![names.png](attachment:53cd23ba-5502-40cf-bc2b-8141cbffd48d.png)

# %% [raw]
# SELECT LEFT(first_name, 4) FROM customer;

# %% [markdown]
# ![fist4.png](attachment:864ffa06-acfe-429c-a948-e2adf0a0b550.png)

# %% [markdown]
# #### INSTR

# %% [markdown]
# A função `INSTR` em SQL é utilizada para encontrar a posição de uma substring dentro de uma string maior. Sua sintaxe geralmente é: `INSTR(string, substring)`
# `

# %% [markdown]
# No exemplo a seguir, demonstraremos o uso combinado das funções `LEFT` e `INSTR` para extrair apenas o nome de usuário de endereços de email.

# %% [markdown]
# ![emails.png](attachment:b38e0674-5786-4f74-a469-4b54fe048eec.png)

# %% [raw]
# SELECT LEFT(email, INSTR(email, '@') - 1);

# %% [markdown]
# ![LEFT.png](attachment:938c04e4-7587-4e48-81f3-27b41235a60a.png)

# %% [markdown]
# #### MID

# %% [markdown]
# A função `MID()` no MySQL é utilizada para extrair uma parte de uma string, com base em uma posição inicial e um comprimento específico. No SQL Server e PostgreSQL, a função equivalente é SUBSTRING(), no Oracle e SQLite: SUBSTR().

# %% [markdown]
# Uma aplicação da função `MID` seria a extração do nome de usuário e domínio de endereços de email:R()

# %% [raw]
# USE sakila;
#
# SELECT MID(email, INSTR(email, '@') + 1) FROM customer;

# %% [markdown]
# ![dominio.png](attachment:e4017909-76f7-46de-a52b-6352a8061f38.png)

# %% [raw]
# USE sakila;
#
# SELECT MID(email, 1, INSTR(email, '@')-1) FROM customer;

# %% [markdown]
# ### FUNÇÕES PARA MANIPULAR DATA E TEMPO

# %% [markdown]
# #### YEAR, MONTH E DAY
#
# As funções `YEAR`, `MONTH` E `DAY` são utilizadas para extrair o ano, o mês e o dia de datad ou datetimes.

# %% [raw]
# USE sakila;
#
# SELECT
#     create_date,
#     YEAR(create_date) AS year,
#     MONTH(create_date) AS month,
#     DAY(create_date) AS day
# from customer;

# %% [markdown]
# ![DATE.png](attachment:733e5fcd-0ace-4138-bcca-62cc70455e82.png)

# %% [markdown]
# #### NOW, CURDATE E CURTIME
# As funções `NOW`, `CURDATE` e `CURTIME`, são usadas para retornar a a data e hora atual do sistema, a data atual do sistema e a hora atual do sistema, respectivamente.

# %% [raw]
# SELECT NOW();
# SELECT CURDATE();
# SELECT CURTIME();

# %% [markdown]
# #### DATEDIFF, DATE_ADD E DATE_SUB
#
# - DATEDIFF: Restorna a diferença, em dias, entre duas datas;
# - DATE_ADD: Adiciona um valor em dias, meses ou anos a uma data.
# - DATE_SUB: Subtrai um valor em dias, meses ou anos a uma data.

# %% [markdown]
# O código a seguir demonstra a utilização da função `DATEDIFF` para calcular a diferença entre as datas da última atualização (`last_update`) e data de retorno (`return_date`).

# %% [raw]
# USE sakila;
#
# SELECT
#     *,
#     DATEDIFF(last_update, return_date) AS date_diff -- Diferença em dias, entre duas datas
# FROM rental;

# %% [markdown]
# ![datedfiff.png](attachment:5b1ec971-36a6-4213-9827-2b3c6d7c4eca.png)

# %% [markdown]
# O código a seguir mostra como adicionar um dia às data da última atualização (`last_update`):

# %% [raw]
# SELECT
#     *,
#     DATE_ADD(last_update, INTERVAL 1 DAY) AS next_day -- Adiciona 1 dia a data da última atualização
# FROM sakila.rental;

# %% [markdown]
# ![next.png](attachment:1c4a4f1c-a821-4020-8bd3-d21cb1e87f0f.png)

# %% [markdown]
# O código a seguir mostra como subtrair 10 dias de uma data:

# %% [raw]
# SELECT
#     *,
#     DATE_SUB(last_update, INTERVAL 10 DAY) AS 10days_before -- Subtraira 10 dias
# FROM sakila.rental;

# %% [markdown]
# ![10daysBefore.png](attachment:491a43e9-2d07-4477-b30c-5ea7a66efb97.png)
